# %%
name_fuclties = {'Basmah':'FC',
                'Juhan':'FM',
                'Ahlam':'FE',
                'Reem':'FS'}
name_fuclties
# Out:
# {'Basmah': 'FC', 'Juhan': 'FM', 'Ahlam': 'FE', 'Reem': 'FS'}

# %%
name_fuclties['Basmah']
# Out:
# 'FC'

# %%
len(name_fuclties)
# Out:
# 4

# %%
del name_fuclties['Basmah']

# %%
name_fuclties
# Out:
# {'Juhan': 'FM', 'Ahlam': 'FE', 'Reem': 'FS'}

# %%
name_fuclties['Reem'] = 'Fuclty of Science'

# %%
name_fuclties
# Out:
# {'Juhan': 'FM', 'Ahlam': 'FE', 'Reem': 'Fuclty of Science'}

# %%
name_fuclties['Muhammad']
# Out:
# 'Fuclty of Science'

# %%
name_fuclties.get('Muhammad')
# Out:
# 'Fuclty of Science'

# %%
name_fuclties.keys()
# Out:
# dict_keys(['Fuad', 'Mahmoud', 'Muhammad'])

# %%
name_fuclties.values()
# Out:
# dict_values(['FE', 'FM', 'Fuclty of Science'])

# %%
name_fuclties_course = {'Ali': ['FC', 'CS'],
                      'Mahmoud' : ['FM', 'GM'],
                      'Fuad' : ['FE', 'EE'],
                      'Muhammad' : ['FS', 'SC']}
name_fuclties_course
# Out:
# {'Ali': ['FC', 'CS'],
#  'Fuad': ['FE', 'EE'],
#  'Mahmoud': ['FM', 'GM'],
#  'Muhammad': ['FS', 'SC']}

# %%
name_fuclties_course['Ali'][1]
# Out:
# 'CS'
